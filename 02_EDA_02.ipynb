# %% [markdown]
# <a href="https://colab.research.google.com/github/hwanython/kaggle-chestXray-penumonia/blob/main/02_EDA_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
data_dir = '/content/drive/MyDrive/AI/01.Kaggle/Chest_X_ray_image/data/chest_xray'
train_dir = os.path.join(data_dir, 'train')
test_dir = os.path.join(data_dir, 'test')

print(train_dir)
# Out:
# /content/drive/MyDrive/AI/01.Kaggle/Chest_X_ray_image/data/chest_xray/train

# %%
train_normal_dir = os.path.join(train_dir, "NORMAL")
train_pneumonia_dir = os.path.join(train_dir, "PNEUMONIA")
test_normal_dir = os.path.join(test_dir, "NORMAL")
test_pneumonia_dir = os.path.join(test_dir, "PNEUMONIA")

# %%
train_data = os.listdir(train_normal_dir) + os.listdir(train_pneumonia_dir)
test_data = os.listdir(test_normal_dir) + os.listdir(test_pneumonia_dir)
train_data_normal = os.listdir(train_normal_dir)
train_data_pneumonia = os.listdir(train_pneumonia_dir)

# %% [markdown]
# #정상데이터 이미지 확인

# %%
import matplotlib.pyplot as plt

fig1=plt.figure(figsize=(15,10))
col = 5; row =4
for i in range(1, col * row +1):
    fig1.add_subplot(row, col, i)
    img = plt.imread(os.path.join(train_normal_dir,train_data_normal[i]))
    plt.imshow(img,cmap='gray')
plt.show()

# %% [markdown]
# # 폐렴 이미지 확인

# %%
fig2=plt.figure(figsize=(15,10))
col = 5; row =4
for i in range(1, col * row +1):
    fig2.add_subplot(row, col, i)
    img = plt.imread(os.path.join(train_pneumonia_dir,train_data_pneumonia[i]))
    plt.imshow(img,cmap='gray')
plt.show()

# %% [markdown]
# #이미지 인텐시티 히스토그램

# %%
import cv2

img = cv2.imread(os.path.join(train_normal_dir,train_data_normal[1]))
# plt.hist(img.ravel());
# plt.show()

plt.hist(img.ravel(),256,[1,256]); plt.show()

# %% [markdown]
# #정상인 이미지 히스토그램

# %%
fig3= plt.figure(figsize=(25,10))
col = 5; row = 4;
for i in range(1, col*row+1):
  fig3.add_subplot(row, col, i)
  img = cv2.imread(os.path.join(train_normal_dir,train_data_normal[i]))
  plt.hist(img.ravel(),256,[1,256]); 
plt.show()

# %% [markdown]
# # 폐렴환자 이미지 히스토그램

# %%
fig4= plt.figure(figsize=(25,10))
col = 5; row = 4;
for i in range(1, col*row+1):
  fig4.add_subplot(row, col, i)
  img = cv2.imread(os.path.join(train_pneumonia_dir,train_data_pneumonia[i]))
  plt.hist(img.ravel(),256,[1,256]); 
plt.show()
